# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
font = {'size': 30}
mpl.rc('font', **font)

# %%
df2 = pd.read_csv("./bases/wdi/Indicators.csv")

# %%
dfmasc = pd.read_csv("./bases/suicide/suicidioMasculinoGlobal.csv")
dffem = pd.read_csv("./bases/suicide/suicidioFemininoGlobal.csv")

# %%
filtro = df2.IndicatorCode.isin(['SP.DYN.LE00.IN','SP.DYN.LE00.FE.IN','SP.DYN.LE00.MA.IN'])
filtro2 = df2.Year > 1999 
filtro3 = df2.Year < 2016
df2 = df2[filtro & filtro3]
df2.replace(["Slovak Republic", "Kyrgyz Republic","St. Lucia","Bahamas, The","Korea, Dem. Rep.","St. Vincent and the Grenadines","Russia"], ['Slovakia', 'Kyrgyzstan', 'Saint Lucia', 'Bahamas', 'Republic of Korea', 'Saint Vincent and Grenadines','Russian Federation'], inplace=True)                                 
filtro4 = df2.CountryName.isin(['Albania', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba', 'Australia', 'Austria', 'Bahamas', 'Bahrain', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Brazil', 'Bulgaria', 'Canada', 'Chile', 'Colombia', 'Costa Rica', 'Croatia', 'Cuba', 'Cyprus', 'Czech Republic', 'Denmark', 'Ecuador', 'El Salvador', 'Estonia', 'Fiji', 'Finland', 'France', 'Georgia', 'Germany', 'Greece', 'Grenada', 'Guatemala', 'Guyana', 'Hungary', 'Iceland', 'Ireland', 'Israel', 'Italy', 'Japan', 'Kazakhstan', 'Kuwait', 'Kyrgyzstan', 'Latvia', 'Lithuania', 'Luxembourg', 'Malta', 'Mauritius', 'Mexico', 'Netherlands', 'New Zealand', 'Norway', 'Panama', 'Paraguay', 'Poland', 'Portugal', 'Puerto Rico', 'Qatar', 'Republic of Korea', 'Romania', 'Russian Federation', 'Saint Lucia', 'Saint Vincent and Grenadines', 'Serbia', 'Seychelles', 'Singapore', 'Slovakia', 'Slovenia', 'South Africa', 'Spain', 'Suriname', 'Sweden', 'Switzerland', 'Thailand', 'Trinidad and Tobago', 'Turkmenistan', 'Ukraine', 'United Kingdom', 'United States', 'Uruguay'])
df2 = df2[filtro2].reset_index(drop=True)
df2.rename(columns={'CountryName':'country','CountryCode':'countrycode'}, inplace=True)
df2
# Out:
# /home/nicoedu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys
#                                         country countrycode  \
# 0                                    Arab World         ARB
# 1                                    Arab World         ARB
# 2                                    Arab World         ARB
# 3                        Caribbean small states         CSS
# 4                        Caribbean small states         CSS
# 5                        Caribbean small states         CSS
# 6                Central Europe and the Baltics         CEB
# 7                Central Europe and the Baltics         CEB
# 8                Central Europe and the Baltics         CEB
# 9       East Asia & Pacific (all income levels)         EAS
# 10      East Asia & Pacific (all income levels)         EAS
# 11      East Asia & Pacific (all income levels)         EAS
# 12        East Asia & Pacific (developing only)         EAP
# 13        East Asia & Pacific (developing only)         EAP
# 14        East Asia & Pacific (developing only)         EAP
# 15                                    Euro area         EMU
# 16                                    Euro area         EMU
# 17                                    Euro area         EMU
# 18    Europe & Central Asia (all income levels)         ECS
# 19    Europe & Central Asia (all income levels)         ECS
# 20    Europe & Central Asia (all income levels)         ECS
# 21      Europe & Central Asia (developing only)         ECA
# 22      Europe & Central Asia (developing only)         ECA
# 23      Europe & Central Asia (developing only)         ECA
# 24                               European Union         EUU
# 25                               European Union         EUU
# 26                               European Union         EUU
# 27     Fragile and conflict affected situations         FCS
# 28     Fragile and conflict affected situations         FCS
# 29     Fragile and conflict affected situations         FCS
# ...                                         ...         ...
# 9780                                    Uruguay         URY
# 9781                                    Uruguay         URY
# 9782                                    Uruguay         URY
# 9783                                 Uzbekistan         UZB
# 9784                                 Uzbekistan         UZB
# 9785                                 Uzbekistan         UZB
# 9786                                    Vanuatu         VUT
# 9787                                    Vanuatu         VUT
# 9788                                    Vanuatu         VUT
# 9789                              Venezuela, RB         VEN
# 9790                              Venezuela, RB         VEN
# 9791                              Venezuela, RB         VEN
# 9792                                    Vietnam         VNM
# 9793                                    Vietnam         VNM
# 9794                                    Vietnam         VNM
# 9795                      Virgin Islands (U.S.)         VIR
# 9796                      Virgin Islands (U.S.)         VIR
# 9797                      Virgin Islands (U.S.)         VIR
# 9798                         West Bank and Gaza         WBG
# 9799                         West Bank and Gaza         WBG
# 9800                         West Bank and Gaza         WBG
# 9801                                Yemen, Rep.         YEM
# 9802                                Yemen, Rep.         YEM
# 9803                                Yemen, Rep.         YEM
# 9804                                     Zambia         ZMB
# 9805                                     Zambia         ZMB
# 9806                                     Zambia         ZMB
# 9807                                   Zimbabwe         ZWE
# 9808                                   Zimbabwe         ZWE
# 9809                                   Zimbabwe         ZWE
#
#                                  IndicatorName      IndicatorCode  Year  \
# 0     Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  2000
# 1       Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  2000
# 2      Life expectancy at birth, total (years)     SP.DYN.LE00.IN  2000
# 3     Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  2000
# 4       Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  2000
# 5      Life expectancy at birth, total (years)     SP.DYN.LE00.IN  2000
# 6     Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  2000
# 7       Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  2000
# 8      Life expectancy at birth, total (years)     SP.DYN.LE00.IN  2000
# 9     Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  2000
# 10      Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  2000
# 11     Life expectancy at birth, total (years)     SP.DYN.LE00.IN  2000
# 12    Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  2000
# 13      Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  2000
# 14     Life expectancy at birth, total (years)     SP.DYN.LE00.IN  2000
# 15    Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  2000
# 16      Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  2000
# 17     Life expectancy at birth, total (years)     SP.DYN.LE00.IN  2000
# 18    Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  2000
# 19      Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  2000
# 20     Life expectancy at birth, total (years)     SP.DYN.LE00.IN  2000
# 21    Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  2000
# 22      Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  2000
# 23     Life expectancy at birth, total (years)     SP.DYN.LE00.IN  2000
# 24    Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  2000
# 25      Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  2000
# 26     Life expectancy at birth, total (years)     SP.DYN.LE00.IN  2000
# 27    Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  2000
# 28      Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  2000
# 29     Life expectancy at birth, total (years)     SP.DYN.LE00.IN  2000
# ...                                        ...                ...   ...
# 9780  Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  2013
# 9781    Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  2013
# 9782   Life expectancy at birth, total (years)     SP.DYN.LE00.IN  2013
# 9783  Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  2013
# 9784    Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  2013
# 9785   Life expectancy at birth, total (years)     SP.DYN.LE00.IN  2013
# 9786  Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  2013
# 9787    Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  2013
# 9788   Life expectancy at birth, total (years)     SP.DYN.LE00.IN  2013
# 9789  Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  2013
# 9790    Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  2013
# 9791   Life expectancy at birth, total (years)     SP.DYN.LE00.IN  2013
# 9792  Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  2013
# 9793    Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  2013
# 9794   Life expectancy at birth, total (years)     SP.DYN.LE00.IN  2013
# 9795  Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  2013
# 9796    Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  2013
# 9797   Life expectancy at birth, total (years)     SP.DYN.LE00.IN  2013
# 9798  Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  2013
# 9799    Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  2013
# 9800   Life expectancy at birth, total (years)     SP.DYN.LE00.IN  2013
# 9801  Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  2013
# 9802    Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  2013
# 9803   Life expectancy at birth, total (years)     SP.DYN.LE00.IN  2013
# 9804  Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  2013
# 9805    Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  2013
# 9806   Life expectancy at birth, total (years)     SP.DYN.LE00.IN  2013
# 9807  Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  2013
# 9808    Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  2013
# 9809   Life expectancy at birth, total (years)     SP.DYN.LE00.IN  2013
#
#           Value
# 0     69.652107
# 1     66.101700
# 2     67.826949
# 3     72.578948
# 4     66.441994
# 5     69.438262
# 6     76.787086
# 7     68.857086
# 8     72.719690
# 9     73.659082
# 10    69.682600
# 11    71.662834
# 12    72.543681
# 13    68.946629
# 14    70.690575
# 15    81.618782
# 16    75.094677
# 17    78.273992
# 18    77.124556
# 19    69.196984
# 20    73.026072
# 21    73.126847
# 22    64.919654
# 23    68.895651
# 24    80.480296
# 25    73.999912
# 26    77.157631
# 27    58.420354
# 28    55.620880
# 29    57.040161
# ...         ...
# 9780  80.503000
# 9781  73.344000
# 9782  76.836195
# 9783  71.668000
# 9784  64.951000
# 9785  68.227585
# 9786  73.738000
# 9787  69.699000
# 9788  71.669244
# 9789  78.320000
# 9790  70.031000
# 9791  74.074415
# 9792  80.461000
# 9793  71.276000
# 9794  75.756488
# 9795  82.800000
# 9796  76.600000
# 9797  79.624390
# 9798  74.974000
# 9799  71.517000
# 9800  73.203341
# 9801  64.969000
# 9802  62.264000
# 9803  63.583512
# 9804  60.965000
# 9805  57.592000
# 9806  59.237366
# 9807  56.872000
# 9808  54.453000
# 9809  55.633000
#
# [9810 rows x 6 columns]

# %%
dfex = df2.groupby(['Year','IndicatorCode']).agg(np.mean).reset_index()
fig, ax = plt.subplots(figsize=(22, 10))
ax.set_title("Expectativa de vida por ano")
dfex.where(dfex['IndicatorCode'] == 'SP.DYN.LE00.IN').dropna().plot( 'Year', 'Value',grid=True, ax=ax,xticks=range(2000,2014), color='y', linewidth=4, label='Ambos')
dfex.where(dfex['IndicatorCode'] == 'SP.DYN.LE00.MA.IN').dropna().plot( 'Year', 'Value',grid=True, ax=ax, linestyle='-', color='skyblue', linewidth=4, label='Homens')
dfex.where(dfex['IndicatorCode'] == 'SP.DYN.LE00.FE.IN').dropna().plot( 'Year', 'Value',grid=True, ax=ax, yticks=range(64,75),linestyle='-', color='lightcoral', linewidth=4, label='Mulheres')
ax.set_xlabel("Ano")
ax.set_ylabel("Expectativa de vida")
# Out:
# Text(0, 0.5, 'Expectativa de vida')

# %%
dfx = dfex[df2['IndicatorCode'] == 'SP.DYN.LE00.MA.IN']
dfx = dfx.rename(columns={'Year':'year'})
dfm = dfmasc[dfmasc.year < 2014].join(dfx.set_index(['year']), on=['year'])
list(map(lambda x:dfm[x].corr(dfm.Value),dfm.columns[1:7]))
# Out:
# /home/nicoedu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# [-0.790964307545365,
#  -0.9455602757211395,
#  -0.9696764786473733,
#  -0.9719448609240073,
#  -0.9775842836025636,
#  -0.9858977213574568]

# %%
dfx = dfex[df2['IndicatorCode'] == 'SP.DYN.LE00.FE.IN']
dfx = dfx.rename(columns={'Year':'year'})
dff = dffem[dffem.year < 2014].join(dfx.set_index(['year']), on=['year'])
list(map(lambda x:dff[x].corr(dff.Value),dff.columns[1:7]))
# Out:
# /home/nicoedu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# [0.7647035788038193,
#  0.329929206254727,
#  -0.0877176261192214,
#  -0.8925027209028754,
#  -0.9811250933353189,
#  -0.989524873805775]

# %%
fig, ax = plt.subplots(figsize=(28, 10))
ax.set_title("Correlação Expectativa de vida vs suicídios - Homens\n(-0.97194486),(-0.97758428),(-0.98589772)")

dfex.where(dfex['IndicatorCode'] == 'SP.DYN.LE00.MA.IN').dropna().plot( 'Year', 'Value',grid=True, ax=ax, linestyle='-', color='red', linewidth=4, label='Expectativa de vida')
ax2 = ax.twinx()
ax2.set_ylabel("Suicídios por 100 mil")
dfmasc.plot(x='year', y='suicidio3554',linewidth=4, ax=ax2, label='35 a 54 anos')
dfmasc.plot(x='year', y='suicidio5574',linewidth=4, ax=ax2,label='55 a 74 anos')
dfmasc.plot(x='year', y='suicidio75',linewidth=4, ax=ax2, label='75+ anos')
ax.set_xlabel("Ano")
ax.set_ylabel("Idade")
# Out:
# Text(0, 0.5, 'Idade')

# %%
fig, ax = plt.subplots(figsize=(28, 10))
ax.set_title("Correlação Expectativa de vida vs suicídios - Mulheres\n(-0.89250272),(-0.98112509),(-0.98952487)")

dfex.where(dfex['IndicatorCode'] == 'SP.DYN.LE00.FE.IN').dropna().plot( 'Year', 'Value',grid=True, ax=ax, linestyle='-', color='red', linewidth=4, label='Expectativa de vida')
ax2 = ax.twinx()
ax2.set_ylabel("Suicídios por 100 mil")
dffem.plot(x='year', y='suicidio3554',linewidth=4, ax=ax2, label='35 a 54 anos')
dffem.plot(x='year', y='suicidio5574',linewidth=4, ax=ax2,label='55 a 74 anos')
dffem.plot(x='year', y='suicidio75',linewidth=4, ax=ax2, label='75+ anos')
ax.set_xlabel("Ano")
ax.set_ylabel("Idade")
# Out:
# Text(0, 0.5, 'Idade')
